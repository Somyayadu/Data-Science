# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ip (c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages)

# %%
import numpy as np
import matplotlib .pyplot as plt 
import pandas as pd
import seaborn as sns

# %%
## seaborn is a library for making statistical 
## graphic in python . it is built on top of

# %%
df=sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.plot()
# Out:
# []

# %%
sns.lineplot(df["total_bill"])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.scatterplot(df["total_bill"])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.scatterplot(x = "total_bill",y="tip",data=df,)
plt.title("scatterplot")
plt.show()

# %%
sns.histplot(df["total_bill"],color="orange",edgecolor="blue")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.barplot(x="day",y="total_bill",data=df,color="red",edgecolor="black")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.kdeplot(df["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
## sns -- 1 categrical 
## 2 numerical -- scatter plot , lineplot -- relational -- relplot

# %%
sns.relplot( x="total_bill",y="tip",data=df,kind="scatter",hue="size")

# %%
sns.relplot( x="total_bill",y="tip",data=df,kind="scatter",hue="sex")

# %%
sns.relplot( x="total_bill",y="tip",data=df,kind="scatter",hue="smoker",style="size",col="day")

# %%
sns.relplot( x="total_bill",y="tip",data=df,kind="scatter",hue="tip",row="day")

# %%
sns.relplot( x="total_bill",y="tip",data=df,kind="scatter",hue="day")

# %%
sns.catplot(x="day",y="total_bill",data=df,
            kind="boxen")

# %%
sns.catplot(x="day",y="total_bill",data=df,
            kind="box")

# %%
sns.catplot(x="day",y="total_bill",data=df,
            kind="bar")

# %%
sns.catplot(x="day",y="total_bill",data=df,          ##owerlaping avoid karta hai
            kind="swarm")

# %%
sns.catplot(x="day",y="total_bill",data=df,
            kind="point")

# %%
sns.catplot(x="day",y="total_bill",data=df,
            kind="violin")

# %%
sns.catplot(x="day",y="total_bill",data=df,
            kind="strip",
            )

# %%
sns.catplot(x="total_bill",data=df,
            kind="count")
plt.show()

# %%
## pointplot -- 

sns.pointplot(x="day",y="total_bill",data=df,hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#box plot -- spread of data inyhe form of box 

sns.boxplot(x="day",y="total_bill",data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day",y="total_bill",data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.pairplot(df)

# %%
sns.histplot(df["tip"],kde=True,color="blue",edgecolor="red")
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.boxenplot(df["tip"])
plt.show()

# %%
sns.catplot(df["tip"])

# %%
sns.countplot(df["tip"])
# Out:
# <Axes: ylabel='count'>

# %%
q1 = df["total_bill"].quantile(0.25)
q3 = df["total_bill"].quantile(0.75)
iqr = q3-q1
lower_limit = q1-1.5*iqr
upper_limit = q3+1.5*iqr
print("lowerlimit=",lower_limit)
print("upperlimit=",upper_limit)
# Out:
# lowerlimit= -2.8224999999999945
# upperlimit= 40.29749999999999

# %%
q1 = df["total_bill"].quantile(0.25)
q3 = df["total_bill"].quantile(0.75)
iqr = q3-q1
lower_limit = q1-1.5*iqr
upper_limit = q3+1.5*iqr
print("lowerlimit=",lower_limit)
print("upperlimit=",upper_limit)

df[df["total_bill"]>upper_limit]
df=df[(df["total_bill"]>lower_limit)&(df["total_bill"]<upper_limit)]
sns.boxplot(df["total_bill"])
# Out:
# lowerlimit= -2.8224999999999945
# upperlimit= 40.29749999999999
# <Axes: ylabel='total_bill'>
